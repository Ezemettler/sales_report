# %%
import pandas as pd

# %%
data_electronics = pd.read_csv('electronics_sales.csv')
data_electronics.head(15)
# Out:
#              Order Date  Order ID                     Product   Product_ean  \
# 0   2019-01-22 21:25:00    141234                      iPhone  5.638009e+12
# 1   2019-01-28 14:15:00    141235    Lightning Charging Cable  5.563320e+12
# 2   2019-01-17 13:33:00    141236            Wired Headphones  2.113973e+12
# 3   2019-01-05 20:33:00    141237            27in FHD Monitor  3.069157e+12
# 4   2019-01-25 11:59:00    141238            Wired Headphones  9.692681e+12
# 5   2019-01-29 20:22:00    141239      AAA Batteries (4-pack)  2.953869e+12
# 6   2019-01-26 12:16:00    141240      27in 4K Gaming Monitor  5.173671e+12
# 7   2019-01-05 12:04:00    141241        USB-C Charging Cable  8.051737e+12
# 8   2019-01-01 10:30:00    141242  Bose SoundSport Headphones  1.508418e+12
# 9   2019-01-22 21:20:00    141243    Apple Airpods Headphones  1.386344e+12
# 10  2019-01-07 11:29:00    141244    Apple Airpods Headphones  4.332899e+12
# ...

# %%
conteo_productos = data_electronics['Product'].value_counts()
print(conteo_productos)
# Out:
# USB-C Charging Cable          21903
# Lightning Charging Cable      21658
# AAA Batteries (4-pack)        20641
# AA Batteries (4-pack)         20577
# Wired Headphones              18882
# Apple Airpods Headphones      15549
# Bose SoundSport Headphones    13325
# 27in FHD Monitor               7507
# iPhone                         6842
# 27in 4K Gaming Monitor         6230
# 34in Ultrawide Monitor         6181
# Google Phone                   5525
# Flatscreen TV                  4800
# Macbook Pro Laptop             4724
# ThinkPad Laptop                4128
# 20in Monitor                   4101
# Vareebadd Phone                2065
# LG Washing Machine              666
# LG Dryer                        646
# Name: Product, dtype: int64

# %%
df_electronics = data_electronics

# %%
# Reemplazamos productos 'LG Washing Machine', 'LG Dryer' y 'Vareebadd Phone' a productos que se vendan más relacionados a smartphones y laptops.
df_electronics['Product'] = df_electronics['Product'].replace('LG Washing Machine', 'Samsung Galaxy Phone')
df_electronics['Product'] = df_electronics['Product'].replace('LG Dryer', 'Dell Inspiron Laptop')
df_electronics['Product'] = df_electronics['Product'].replace('Vareebadd Phone', 'HP Pavilion Laptop')
df_electronics['Product'] = df_electronics['Product'].replace('Flatscreen TV', 'Motorola Edge Phone')

# Selecciona las filas con nombre de producto y les asigna la marca.
df_electronics.loc[df_electronics['Product'] == 'iPhone', 'brand'] = 'Apple'
df_electronics.loc[df_electronics['Product'] == 'Macbook Pro Laptop', 'brand'] = 'Apple'
df_electronics.loc[df_electronics['Product'] == 'Apple Airpods Headphones', 'brand'] = 'Apple'
df_electronics.loc[df_electronics['Product'] == 'USB-C Charging Cable', 'brand'] = 'Apple'
df_electronics.loc[df_electronics['Product'] == 'Bose SoundSport Headphones', 'brand'] = 'Bose'
df_electronics.loc[df_electronics['Product'] == 'Google Phone', 'brand'] = 'Google'
df_electronics.loc[df_electronics['Product'] == 'Lightning Charging Cable', 'brand'] = 'Generic'
df_electronics.loc[df_electronics['Product'] == 'AAA Batteries (4-pack)', 'brand'] = 'Duracell'
df_electronics.loc[df_electronics['Product'] == 'AA Batteries (4-pack)', 'brand'] = 'Duracell'
df_electronics.loc[df_electronics['Product'] == 'Wired Headphones', 'brand'] = 'Sony'
df_electronics.loc[df_electronics['Product'] == '27in FHD Monitor', 'brand'] = 'Samsung'
df_electronics.loc[df_electronics['Product'] == '27in 4K Gaming Monitor', 'brand'] = 'Asus'
df_electronics.loc[df_electronics['Product'] == '34in Ultrawide Monitor', 'brand'] = 'ViewSonic'
df_electronics.loc[df_electronics['Product'] == 'ThinkPad Laptop', 'brand'] = 'Lenovo'
df_electronics.loc[df_electronics['Product'] == '20in Monitor', 'brand'] = 'Dell'
df_electronics.loc[df_electronics['Product'] == 'Samsung Galaxy Phone', 'brand'] = 'Samsung'      
df_electronics.loc[df_electronics['Product'] == 'Dell Inspiron Laptop', 'brand'] = 'Dell'                   
df_electronics.loc[df_electronics['Product'] == 'HP Laptop', 'brand'] = 'HP'
df_electronics.loc[df_electronics['Product'] == 'Motorola Edge Phone', 'brand'] = 'Motorola'

# Imprime el dataframe restante luego de modificaciones
df_electronics.head(10)
# Out:
#             Order Date  Order ID                     Product    Product_ean  \
# 0  2019-01-22 21:25:00    141234                      iPhone  5638008983335
# 1  2019-01-28 14:15:00    141235    Lightning Charging Cable  5563319511488
# 2  2019-01-17 13:33:00    141236            Wired Headphones  2113973395220
# 3  2019-01-05 20:33:00    141237            27in FHD Monitor  3069156759167
# 4  2019-01-25 11:59:00    141238            Wired Headphones  9692680938163
# 5  2019-01-29 20:22:00    141239      AAA Batteries (4-pack)  2953868554188
# 6  2019-01-26 12:16:00    141240      27in 4K Gaming Monitor  5173670800988
# 7  2019-01-05 12:04:00    141241        USB-C Charging Cable  8051736777568
# 8  2019-01-01 10:30:00    141242  Bose SoundSport Headphones  1508418177978
# 9  2019-01-22 21:20:00    141243    Apple Airpods Headphones  1386344211590
#
#        category                         Purchase Address  Quantity Ordered  \
# ...

# %%
df_electronics.isna().sum()
# Out:
# Order Date             0
# Order ID               0
# Product                0
# Product_ean            0
# category               0
# Purchase Address       0
# Quantity Ordered       0
# Price Each             0
# Cost price             0
# turnover               0
# margin                 0
# brand               2065
# dtype: int64

# %%
# EAN: European Article Number, es un sistema de códigos de barras utilizado para identificar productos en el comercio y la industria a nivel internacional. 
#      Cada producto suele tener un número único de EAN que se utiliza para identificarlo de manera única.

# Convierte la columna product_ean al formato de número entero sin decimales
df_electronics['Product_ean'] = pd.to_numeric(df_electronics['Product_ean'], errors='coerce').astype('Int64')
df_electronics.head(10)
# Out:
#             Order Date  Order ID                     Product    Product_ean  \
# 0  2019-01-22 21:25:00    141234                      iPhone  5638008983335
# 1  2019-01-28 14:15:00    141235    Lightning Charging Cable  5563319511488
# 2  2019-01-17 13:33:00    141236            Wired Headphones  2113973395220
# 3  2019-01-05 20:33:00    141237            27in FHD Monitor  3069156759167
# 4  2019-01-25 11:59:00    141238            Wired Headphones  9692680938163
# 5  2019-01-29 20:22:00    141239      AAA Batteries (4-pack)  2953868554188
# 6  2019-01-26 12:16:00    141240      27in 4K Gaming Monitor  5173670800988
# 7  2019-01-05 12:04:00    141241        USB-C Charging Cable  8051736777568
# 8  2019-01-01 10:30:00    141242  Bose SoundSport Headphones  1508418177978
# 9  2019-01-22 21:20:00    141243    Apple Airpods Headphones  1386344211590
#
#        category                         Purchase Address  Quantity Ordered  \
# ...

# %%
# Cambia el nombre de la columna 'catégorie' a 'category'
df_electronics.rename(columns={'catégorie': 'category'}, inplace=True)
df_electronics.head()
# Out:
#             Order Date  Order ID                   Product    Product_ean  \
# 0  2019-01-22 21:25:00    141234                    iPhone  5638008983335
# 1  2019-01-28 14:15:00    141235  Lightning Charging Cable  5563319511488
# 2  2019-01-17 13:33:00    141236          Wired Headphones  2113973395220
# 3  2019-01-05 20:33:00    141237          27in FHD Monitor  3069156759167
# 4  2019-01-25 11:59:00    141238          Wired Headphones  9692680938163
#
#        category                       Purchase Address  Quantity Ordered  \
# 0     Celulares        944 Walnut St, Boston, MA 02215                 1
# 1  Alimentation       185 Maple St, Portland, OR 97035                 1
# 2     Vêtements  538 Adams St, San Francisco, CA 94016                 2
# 3        Sports     738 10th St, Los Angeles, CA 90001                 1
# 4  Électronique          387 10th St, Austin, TX 73301                 1
#
#    Price Each  Cost price  turnover    margin    brand
# ...

# %%
# Verificamos que cantidad de productos hay por cada categoria
df_electronics['category'].value_counts()
# Out:
# Sports          45206
# Électronique    44651
# Alimentation    44627
# Vêtements       44624
# Celulares        6842
# Name: category, dtype: int64

# %%
# Cambia el nombre de categoria a las filas cuyo nombre de producto cumple con la condicion.
df_electronics.loc[df_electronics['Product'] == 'USB-C Charging Cable', 'category'] = 'Accesorios'
df_electronics.loc[df_electronics['Product'] == 'Lightning Charging Cable', 'category'] = 'Accesorios'
df_electronics.loc[df_electronics['Product'] == 'AAA Batteries (4-pack)', 'category'] = 'Accesorios'
df_electronics.loc[df_electronics['Product'] == 'AA Batteries (4-pack)', 'category'] = 'Accesorios'
df_electronics.loc[df_electronics['Product'] == 'Wired Headphones', 'category'] = 'Auriculares'
df_electronics.loc[df_electronics['Product'] == 'Apple Airpods Headphones', 'category'] = 'Auriculares'
df_electronics.loc[df_electronics['Product'] == 'Bose SoundSport Headphones', 'category'] = 'Auriculares'
df_electronics.loc[df_electronics['Product'] == '27in FHD Monitor', 'category'] = 'Monitores'
df_electronics.loc[df_electronics['Product'] == 'iPhone', 'category'] = 'Celulares'
df_electronics.loc[df_electronics['Product'] == '27in 4K Gaming Monitor', 'category'] = 'Monitores'
df_electronics.loc[df_electronics['Product'] == '34in Ultrawide Monitor', 'category'] = 'Monitores'
df_electronics.loc[df_electronics['Product'] == 'Google Phone', 'category'] = 'Celulares'
df_electronics.loc[df_electronics['Product'] == 'Motorola Edge Phone', 'category'] = 'Celulares'
df_electronics.loc[df_electronics['Product'] == 'Macbook Pro Laptop', 'category'] = 'Computadoras'
df_electronics.loc[df_electronics['Product'] == 'ThinkPad Laptop', 'category'] = 'Computadoras'
df_electronics.loc[df_electronics['Product'] == '20in Monitor', 'category'] = 'Monitores'
df_electronics.loc[df_electronics['Product'] == 'HP Pavilion Laptop', 'category'] = 'Computadoras'
df_electronics.loc[df_electronics['Product'] == 'Samsung Galaxy Phone', 'category'] = 'Celulares'
df_electronics.loc[df_electronics['Product'] == 'Dell Inspiron Laptop', 'category'] = 'Computadoras'                        


# Imprime el dataframe luego de las odificaciones.
df_electronics.head(10)
# Out:
#             Order Date  Order ID                     Product    Product_ean  \
# 0  2019-01-22 21:25:00    141234                      iPhone  5638008983335
# 1  2019-01-28 14:15:00    141235    Lightning Charging Cable  5563319511488
# 2  2019-01-17 13:33:00    141236            Wired Headphones  2113973395220
# 3  2019-01-05 20:33:00    141237            27in FHD Monitor  3069156759167
# 4  2019-01-25 11:59:00    141238            Wired Headphones  9692680938163
# 5  2019-01-29 20:22:00    141239      AAA Batteries (4-pack)  2953868554188
# 6  2019-01-26 12:16:00    141240      27in 4K Gaming Monitor  5173670800988
# 7  2019-01-05 12:04:00    141241        USB-C Charging Cable  8051736777568
# 8  2019-01-01 10:30:00    141242  Bose SoundSport Headphones  1508418177978
# 9  2019-01-22 21:20:00    141243    Apple Airpods Headphones  1386344211590
#
#       category                         Purchase Address  Quantity Ordered  \
# ...

# %%
df_electronics['category'].value_counts()
# Out:
# Accesorios      84779
# Auriculares     47756
# Monitores       24019
# Celulares       17833
# Computadoras    11563
# Name: category, dtype: int64
